# %% [markdown]
# # Supervised Machine Learning: Regression and Classification

# %% [markdown]
# ## Week 1 - Exercise / Assessment

# %% [markdown]
# As you can recall, in week 1 of the supervised machine learning: Regression and Classification course, you learned about univariate linear regression (one variable linear regression). This included key concepts such as the linear regression hypothesis function, cost function, and gradient descent algorithm.
#
# This exercise focuses on testing your application skills of linear regression to real-world research problem.

# %% [markdown]
# ## Problem
#
# You are going to implement a univariate linear regression to estimate the cooling load and heating load of residential buildings.
#
# The dataset you're going to use comprises 768 samples and 8 features (independent variables). The features are relative compactness, surface area, wall area, roof area, overall height, orientation, glazing area, glazing area distribution. The two output variables (dependent variables) are heating load (HL) and cooling load (CL), of residential buildings.
#
# You can download the dataset from [here](http://archive.ics.uci.edu/ml/datasets/energy+efficiency)
# **Note:** _Click the **Data Folder** and then **ENB2012_data.xlsx** to download the dataset from the link above_
#
# Using a simple linear regression model, we can predict the heating and
# cooling loads for each of the aferomentioned features of a building.
#
# This dataset and work is based on a scientific article which provides
# some analysis on this data set: Feel free to read more about the study - [A. Tsanas, A. Xifara: 'Accurate quantitative estimation of energy performance of residential buildings using statistical machine learning tools', Energy and Buildings, Vol. 49, pp. 560-567,2012](https://www.sciencedirect.com/science/article/pii/S037877881200151X?casa_token=izQv4x7bLl4AAAAA:jg0jkGXmw5B-UHPLVbi4x_RQf6b8sAgVTD9TpcvFJ1AjdJ7E46bNKST3Nay4KuB9DPM9aeN4we4)
#
# For this problem, several tasks have been defined to be completed.
#
# Some of the functions of the Task have already been implemented while some are left for you to implement.
#
# **##TODO** Tag is used to indicate the functions or sections that you must implement.
#
# **##Completed** Tag is used to indicate the functions that have already been completed.

# %% [markdown]
# ## Import Libraries

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (7.7.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipywidgets) (6.13.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipywidgets) (1.1.0)
# Requirement already satisfied: ipython>=4.0.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipywidgets) (7.32.0)
# Requirement already satisfied: nbformat>=4.2.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipywidgets) (5.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipywidgets) (3.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: psutil in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: tornado>=6.1 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: packaging in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: debugpy>=1.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.3.0)
# Requirement already satisfied: nest-asyncio in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: decorator in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: backcall in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pickleshare in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pygments in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (2.12.0)
# Requirement already satisfied: jedi>=0.16 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.36)
# Requirement already satisfied: setuptools>=18.5 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (65.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: jupyter-core in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.11.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.11.3)
# Requirement already satisfied: fastjsonschema in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.17.3)
# Requirement already satisfied: notebook>=4.4.1 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from importlib-metadata>=3.6->nbformat>=4.2.0->ipywidgets) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from importlib-metadata>=3.6->nbformat>=4.2.0->ipywidgets) (3.11.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (5.7.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (22.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: pyzmq>=22.3 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: entrypoints in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: prometheus-client in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.14.1)
# Requirement already satisfied: nbconvert>=5 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.0)
# Requirement already satisfied: argon2-cffi in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.3.0)
# Requirement already satisfied: jinja2 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.17.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.8)
# Requirement already satisfied: jupyter-server>=1.8 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.2)
# Requirement already satisfied: tinycss2 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.1)
# Requirement already satisfied: bleach in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.0.0)
# Requirement already satisfied: beautifulsoup4 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.1)
# Requirement already satisfied: defusedxml in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: six>=1.5 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: websocket-client in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.58.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.5.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: pycparser in /home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21)
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: '/home/beltus/anaconda3/envs/codebase/lib/python3.7/site-packages/numpy-1.21.5.dist-info/METADATA'

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import ipywidgets as widgets

import warnings
warnings.filterwarnings("ignore")

# %matplotlib widget

# %% [markdown]
# In case you face the error _‘ModuleNotFoundError: No module named ‘ipympl’_ , Read the article https://paddyharrison.medium.com/matplotlib-display-problems-in-jupyter-dfd0bb189d2b

# %% [markdown]
# ## Task 1: Read  Dataset into Notebook
#
# Instructions: Write a function that reads the *ENB2012_data.xlsx* dataset into jupyter notebook
#
# Check this [link](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) to learn how to read file using pandas
#
# Note: X1, X2,.....,X8 represent the independent variables in the dataset. Y1 and Y2 represent the dependent variables

# %%
#Imports
import pandas as pd

# %%
##Completed - Function to read excel file
def read_excel(file_path):
    """
    Reads an excel file into jupyter notebook as pandas dataframe
    
    Args:
        file_path(str): dataset file path
    """
    #read dataset file using pandas
    data_df = pd.read_excel(file_path) # complete this line
    
    return data_df

##TODO - replace filepath with your own dataset file path

filepath = "ENB2012_data.xlsx"
data_df = read_excel(filepath)

data_df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %% [markdown]
# ## Task 2: Normalize Dataset between 0 - 1

# %%
##Completed - Scale the data between 0 - 1 
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(data_df)
scaled_df = pd.DataFrame(scaled_df, columns=['X1','X2','X3','X4','X5','X6','X7','X8', 'Y1', 'Y2'])
#scaled_df.head()

# %% [markdown]
# ## Task 2: Explore and Visualize Data

# %% [markdown]
# ### Task 2.1: Statistical Exploration of Data
# * (Optinal) - Feel free to explore the dataset and gain insights using other methods and libraries

# %%
##Completed 
scaled_df.describe()
# Out:
#                X1          X2          X3          X4          X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     0.400463    0.534722    0.428571    0.601852    0.500000    0.500000
# std      0.293826    0.299613    0.254382    0.409668    0.500326    0.372921
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.173611    0.312500    0.285714    0.277778    0.000000    0.250000
# 50%      0.361111    0.541667    0.428571    0.666667    0.500000    0.500000
# 75%      0.583333    0.770833    0.571429    1.000000    1.000000    0.750000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                X7          X8          Y1          Y2
# count  768.000000  768.000000  768.000000  768.000000
# mean     0.585938    0.562500    0.439396    0.368644
# std      0.333051    0.310192    0.272046    0.256216
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.250000    0.350000    0.188258    0.127121
# 50%      0.625000    0.600000    0.348881    0.301104
# 75%      1.000000    0.800000    0.691763    0.598775
# max      1.000000    1.000000    1.000000    1.000000

# %% [markdown]
# ### Task 2.2: Visualize Dataset Features

# %%
def create_scatter(feature1, feature2):
    with plt.style.context("ggplot"):
        fig = plt.figure(figsize=(8,4))

        plt.scatter(x = scaled_df[feature1],
                    y = scaled_df[feature2],
                    c= np.random.rand(scaled_df.shape[0]),
                    s=20
                   )

        plt.xlabel(feature1.capitalize())
        plt.ylabel(feature2.capitalize())

        plt.title("%s vs %s"%(feature1.capitalize(), feature2.capitalize()))

# %%
scaled_df.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'Y1', 'Y2'], dtype='object')

# %%
##TODO - Using the interactive plot, select different features and visualize their scatter plot

widgets.interact(create_scatter, feature1=scaled_df.columns[0], feature2=scaled_df.columns[-1])
# Out:
# interactive(children=(Text(value='X1', description='feature1'), Text(value='Y2', description='feature2'), Outp…
# <function __main__.create_scatter(feature1, feature2)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Task 3: Prepare Dataset Training

# %%
## TODO - Assign each variable in the dataset dataframe to a new variable. 

#independent variables
x1 = scaled_df.iloc[:,0].to_numpy() #extract the first independent variable and convert to numpy()

#TODO - Complete the remaining

x2 = scaled_df.iloc[:,1].to_numpy()
x3 = scaled_df.iloc[:,2].to_numpy()
x4 = scaled_df.iloc[:,3].to_numpy()
x5 = scaled_df.iloc[:,4].to_numpy()
x6 = scaled_df.iloc[:,5].to_numpy()
x7 = scaled_df.iloc[:,6].to_numpy()
x8 = scaled_df.iloc[:,7].to_numpy()

#Dependent variables
y1 = scaled_df.iloc[:,8].to_numpy()
y2 = scaled_df.iloc[:,9].to_numpy()

# %% [markdown]
# ## Task 4: Build Linear Regression Model
#
# You'll implement the hypothesis, cost function and gradient descent algorithm as described in the lectures.
#
# ![image.png](attachment:image.png)

# %%
## TODO - Implement hypothesis
def h(x, b = 0, w = 0):
    """
    calculates the predicted values (or predicted targets) for a given set of inputs and thetas.
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    """
    
    #complete the function 
    h_p = b + x*w
    return h_p 

# TODO - Implement the cost Function
def compute_cost(x, y, w, b):
   
    m = x.shape[0] 
    cost = 0
    
    for i in range(m):
        f_wb = w * x[i] + b
        cost = cost + (f_wb - y[i])**2
    total_cost = 1 / (2 * m) * cost

    return total_cost

### TODO -  Implement Gradient Function

# def compute_gradient(x, y, w, b): 
#     """
#     Computes the gradient for linear regression 
#     Args:
#       x (ndarray (m,)): Data, m examples 
#       y (ndarray (m,)): target values
#       w,b (scalar)    : model parameters  
#     Returns
#       dj_dw (scalar): The gradient of the cost w.r.t. the parameters w
#       dj_db (scalar): The gradient of the cost w.r.t. the parameter b     
#      """
    
#     #complete function
#     m = x.shape[0]    
#     dj_dw = 0
#     dj_db = 0
    
#     for i in range(m):   
#         dj_dw += (h(x, b, w)- y[i]) * x[i] 
#         dj_db += h(x, b, w) - y[i] 
#     dj_dw = dj_dw / m 
#     dj_db = dj_db / m 
        
#     return dj_dw, dj_db

def compute_gradient(x, y, w, b): 
    """
    Computes the gradient for linear regression 
    Args:
      x (ndarray (m,)): Data, m examples 
      y (ndarray (m,)): target values
      w,b (scalar)    : model parameters  
    Returns
      dj_dw (scalar): The gradient of the cost w.r.t. the parameters w
      dj_db (scalar): The gradient of the cost w.r.t. the parameter b     
     """
    
    # Number of training examples
    m = x.shape[0]    
    dj_dw = 0
    dj_db = 0
    
    for i in range(m):  
        f_wb = h(x[i], b, w)
        dj_dw += (f_wb - y[i]) * x[i] 
        dj_db += f_wb - y[i] 
    dj_dw = dj_dw / m 
    dj_db = dj_db / m 
        
    return dj_dw, dj_db

# Completed - Gradient Descent
def gradient_descent(x_train, y_train, w_init, b_init, alpha, num_iters):
    
    b = b_init
    w = w_init
    
    diff = compute_cost(x_train, y_train, w, b)
    
    print("initial Cost: {}".format(compute_cost(x_train, y_train, w, b)))

    for i in range(num_iters):
        # Calculate the gradient and update the parameters using gradient_function
        dj_dw, dj_db = compute_gradient(x_train, y_train, w , b) 
        
        # Update Parameters using equation (3) above
        b = b - alpha * dj_db                            
        w = w - alpha * dj_dw   
        
    return w, b


#Function to predict output - Completed

def predict(x, w, b):
    """
    Predicts the output value given the input x and coefficients w and b
    """

    m = x.shape[0] #number of test samples
    
    y_preds = []
    
    for i in range(m):
        
        y_pred = w * x[i] + b
        
        y_preds.append(y_pred)
        
    return np.array(y_preds)

# %% [markdown]
# ## Task 5: Train Linear Regression Model With Gradient Descent
#
#  * For each of the independent variables (x1, x2, .... , x8)run gradient descent algorithm to find the final coefficients (w_final, b_final).
#
# * Run this exercise for each dependent variable y1 and y2 (cooling and heating load).
#
# * Print _w_final_ and _b_final_ for each of the gradient descent runs. Note: There are 16 runs of gradient descent you must perform.
#
# * For example: (x1,y1), (x1, y2) , (x2, y1, x2, y2) ..... (x8, y1), (x8,y2)

# %% [markdown]
# ### Task 5.1: Split  Dataset into Training and Test set
#
# * Split each of the independent and dependent variables into 80% training set and 20% training set. Check this [link](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) to easily split dataset
#
# * Run gradient descent on the training samples to find the coeficients (w_final, and b_final)
#
# * Using the w_final and b_final, compute the predicted y-values
# * Use the setting below for your runs.
#
# ##### initialize parameters
# w_init = 0.1
#
# b_init = 0.5
#
# ##### Gradient descent settings
# iterations = 10000
#
# tmp_alpha = 0.01

# %% [markdown]
# ### Example Run: Gradient Descent for X1, Y1

# %%
from sklearn.model_selection import train_test_split

# initialize parameters
w_init = 0.1
b_init = 0.5

# Gradient descent settings
iterations = 10000
tmp_alpha = 0.01


# using the train test split function
x1_train,x1_test, y1_train, y1_test = train_test_split(x1,y1, random_state=104,test_size = 0.25, shuffle=True)

# run gradient descent for x1, y1
w_final, b_final = gradient_descent(x1_train ,y1_train, w_init, b_init, tmp_alpha, iterations)
print(f"w_final , b_final: ({w_final:8.4f},{b_final:8.4f})")
# Out:
# initial Cost: 0.03783158789943419
# w_final , b_final: (  0.5803,  0.2026)

# %% [markdown]
# ## Task 6:  Evaluate Model - Mean Square Error
#
# Using the test samples, and the final coefficients obtained from running gradient descent, compute the mean square error of the predicted cooling (Y1) and (Y2) loads.
# ![image.png](attachment:image.png)

# %%
## TODO - Implement evaluate_model() function which basically computes 
#the mean square error between the true output variables and predicted output variables

def evaluate_model(y_true, y_preds):
    
    """
    Args:
        y_true: true output values
        y_preds: model predicted output values
        
    Return:
        return MSE
    """
    # Complete MSE function
    MSE = np.sum((y_true-y_preds)**2)/y_true.shape[0]
    
    return MSE

# %%
x_train[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File g:\soft\python3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File g:\soft\python3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File g:\soft\python3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 x_train[0]
#
# File g:\soft\python3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File g:\soft\python3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %%
y_test
# Out:
#            Y1
# 118  0.730925
# 153  0.551631
# 175  0.126449
# 522  0.289836
# 737  0.969264
# ..        ...
# 696  0.225398
# 265  0.117552
# 152  0.523052
# 674  0.706390
# 78   0.126449
#
# [192 rows x 1 columns]

# %%
x_train,x_test, y_train, y_test = train_test_split(scaled_df[scaled_df.columns[0:8]],scaled_df[scaled_df.columns[8:9]], random_state=104,test_size = 0.25, shuffle=True)
for i in range(8):
    for j in range(2):
        # using the train test split function
        

        # run gradient descent for x1, y1
        w_final, b_final = gradient_descent(x_train[x_train.columns[i]].to_numpy() ,y_train[y_train.columns[-j]].to_numpy(), w_init, b_init, tmp_alpha, iterations)
        print(f"x{i}y{j}_w_final , b_final: ({w_final:8.4f},{b_final:8.4f})")
        y_pred = predict(x_test[x_test.columns[i]].to_numpy(), w_final, b_final)
        print("err:", evaluate_model(y_test.to_numpy(), y_pred))
# Out:
# initial Cost: 0.03783158789943419
# x0y0_w_final , b_final: (  0.5803,  0.2026)
# err: 19.731190569569833
# initial Cost: 0.03783158789943419
# x0y1_w_final , b_final: (  0.5803,  0.2026)
# err: 19.731190569569833
# initial Cost: 0.04985120260286773
# x1y0_w_final , b_final: ( -0.6005,  0.7563)
# err: 20.38784720493678
# initial Cost: 0.04985120260286773
# x1y1_w_final , b_final: ( -0.6005,  0.7563)
# err: 20.38784720493678
# initial Cost: 0.03995325707884356
# x2y0_w_final , b_final: (  0.4724,  0.2352)
# err: 17.02900111750701
# initial Cost: 0.03995325707884356
# x2y1_w_final , b_final: (  0.4724,  0.2352)
# err: 17.02900111750701
# initial Cost: 0.055311974626969275
# x3y0_w_final , b_final: ( -0.5738,  0.7839)
# err: 24.854548621401644
# initial Cost: 0.055311974626969275
# x3y1_w_final , b_final: ( -0.5738,  0.7839)
# err: 24.854548621401644
# initial Cost: 0.03260345981125763
# x4y0_w_final , b_final: (  0.4842,  0.1964)
# err: 25.46025768991444
# initial Cost: 0.03260345981125763
# x4y1_w_final , b_final: (  0.4842,  0.1964)
# err: 25.46025768991444
# initial Cost: 0.04401788561985132
# x5y0_w_final , b_final: (  0.0163,  0.4262)
# err: 14.317870047885608
# initial Cost: 0.04401788561985132
# x5y1_w_final , b_final: (  0.0163,  0.4262)
# err: 14.317870047885608
# initial Cost: 0.04257284539894927
# x6y0_w_final , b_final: (  0.2330,  0.2963)
# err: 15.403175111239515
# initial Cost: 0.04257284539894927
# x6y1_w_final , b_final: (  0.2330,  0.2963)
# err: 15.403175111239515
# initial Cost: 0.044073345094053244
# x7y0_w_final , b_final: (  0.0866,  0.3847)
# err: 14.469131255366987
# initial Cost: 0.044073345094053244
# x7y1_w_final , b_final: (  0.0866,  0.3847)
# err: 14.469131255366987

# %% [markdown]
# ### Run Cell To Test MSE function implementation

# %%
##Test evaluate_model() function by run
import unittest

class TestNotebook(unittest.TestCase):
    
    def test_add(self):
        self.assertEqual(evaluate_model(np.array([2 , 2]), np.array([1.5 , 1.5])), 0.25)
        

unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_add (__main__.TestNotebook) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK

# %% [markdown]
# ## Task 7: Answer the following Questions
#
# * Based on the training and evaluation of each of the univariate linear regression models, identify which of the univariate variables best approximates the output Y1, and Y2.
#
# * Which one of the independent variables performs the worse in approximate Y1, and Y2 outputs when trained with linear regression.

# %% [markdown]
# Best predictor: X6
# Worst predictor: X5
